# %%
import pandas as pd
import dask.dataframe as dd
from pathlib import Path
from sqlalchemy import create_engine, text

# %%
#Reading in the source file for the project
file_path = 'Resources/wdl_data_en_reduced.csv'
# Specifying encoding as'ISO-8859-1' to read file
loc_df = pd.read_csv(file_path, encoding='utf-8')
# Out:
# C:\Users\Cait\AppData\Local\Temp\ipykernel_3208\2306786982.py:4: DtypeWarning: Columns (0,20,33,34,36,37,41,42,43,49,52,54,55,62,63,66,69,70,71,72,74,76,81,82,84,85,86,87) have mixed types. Specify dtype option on import or set low_memory=False.
#   loc_df = pd.read_csv(file_path, encoding='utf-8')

# %%
loc_df.columns
# Out:
# Index(['wdl_id', 'title', 'collection', 'description', 'wdl_url',
#        'Type of Item', 'Institution', 'Photographer', 'Date Created',
#        'Subject Date', 'Place', 'Dewey Decimal Code', 'Additional Subjects',
#        'Physical Description', 'Creator', 'Publisher', 'Language', 'Artist',
#        'Cartographer', 'Note', 'Delineator', 'Author', 'Surveyor', 'Compiler',
#        'Translator', 'Contributor', 'Engraver', 'Cinematographer', 'Director',
#        'Illustrator', 'Sponsor', 'Draftsman', 'Editor', 'Corrector',
#        'Responsible Party', 'Calligrapher', 'Interviewee', 'Interviewer',
#        'Associated Name', 'Printer', 'Lithographer', 'Donor',
#        'Recording Engineer', 'Musician', 'Composer', 'Architect', 'References',
#        'Attributed Name', 'Dedicatee', 'Signer', 'Copyright Holder',
#        'Collector', 'Printmaker', 'Copyright claimant', 'Performer', 'Owner',
#        'Commentator', 'Etcher', 'Wood-engraver', 'Scribe',
#        'Author of Introduction, etc.', 'Author of Afterword, Colophon, etc.',
#        'Scientific advisor', 'Speaker', 'Commentator for Written Text',
#        'Illuminator', 'Librettist', 'Client', 'Transcriber', 'Collaborator',
#        'Producer', 'Videographer', 'Vocalist', 'Patron', 'Funder', 'Annotator',
#        'Woodcutter', 'Designer', 'Author in Quotations or Text Extracts',
#        'Lyricist', 'Type Designer', 'Animator', 'Writer of added text',
#        'Project Director', 'Dubious Author', 'Censor', 'Engineer', 'Lead',
#        'Publishing Director', 'Singer', 'Binder', 'Originator', 'Typographer',
#        'Book producer', 'Narrator', 'Colorist', 'Arranger', 'Recipient',
#        'Correspondent'],
#       dtype='object')

# %%
#loc_df['item_id'] = loc_df.index
#loc_df.head()

# %%
loc_df.drop(columns=['wdl_id','Creator','Delineator', 'Author', 'Surveyor', 'Compiler',
       'Translator', 'Contributor', 'Engraver', 'Cinematographer', 'Director',
       'Illustrator', 'Sponsor', 'Draftsman', 'Editor', 'Corrector',
       'Responsible Party', 'Calligrapher', 'Interviewee', 'Interviewer',
       'Associated Name', 'Printer', 'Lithographer', 'Donor',
       'Recording Engineer', 'Musician', 'Composer', 'Architect', 'References',
       'Attributed Name', 'Dedicatee', 'Signer', 'Copyright Holder',
       'Collector', 'Printmaker', 'Copyright claimant', 'Performer', 'Owner',
       'Commentator', 'Etcher', 'Wood-engraver', 'Scribe',
       'Author of Introduction, etc.', 'Author of Afterword, Colophon, etc.',
       'Scientific advisor', 'Speaker', 'Commentator for Written Text',
       'Illuminator', 'Librettist', 'Client', 'Transcriber', 'Collaborator',
       'Producer', 'Videographer', 'Vocalist', 'Patron', 'Funder', 'Annotator',
       'Woodcutter', 'Designer', 'Author in Quotations or Text Extracts',
       'Lyricist', 'Type Designer', 'Animator', 'Writer of added text',
       'Project Director', 'Dubious Author', 'Censor', 'Engineer', 'Lead',
       'Publishing Director', 'Singer', 'Binder', 'Originator', 'Typographer',
       'Book producer', 'Narrator', 'Colorist', 'Arranger', 'Recipient',
       'Correspondent','Creator','Language', 'Artist',
       'Cartographer', 'Note','Photographer','Place','Subject Date','Additional Subjects'], inplace=True)
loc_df.head()
# Out:
#                                                title  \
# 0  Antietam, Maryland. Allan Pinkerton, President...
# 1  Chola Woman, Full-Length Portrait, Standing, F...
# 2           Maps of Ezo, Sakhalin, and Kuril Islands
# 3                          Warrior Asahina Kobayashi
# 4     Manuscript Map of Dagua River Region, Colombia
#
#                                 collection  \
# 0                                      NaN
# 1   Frank and Frances Carpenter Collection
# 2                                      NaN
# 3  Japanese Prints and Drawings Collection
# 4                                      NaN
#
#                                          description  \
# 0  At the outset of the U.S. Civil War, Mathew Br...
# 1  This photograph of a Bolivian woman is from th...
# 2  This map was made by Fujita Junsai and publish...
# 3  The Japanese art of Ukiyo-e (“Pictures of the ...
# 4  This beautiful pen-and-ink and watercolor map ...
#
#                          wdl_url         Type of Item          Institution  \
# 0  https://www.wdl.org/en/item/1  Prints, Photographs  Library of Congress
# 1  https://www.wdl.org/en/item/2  Prints, Photographs  Library of Congress
# 2  https://www.wdl.org/en/item/3                 Maps  Library of Congress
# 3  https://www.wdl.org/en/item/4  Prints, Photographs  Library of Congress
# 4  https://www.wdl.org/en/item/5                 Maps  Library of Congress
#
#   Date Created Dewey Decimal Code  \
# 0   1862-10-03                973
# 1         1911                391
# 2         1854                912
# 3         1862            769|792
# 4         1764                912
#
#                                 Physical Description           Publisher
# 0                  1 negative : glass, wet collodion                 NaN
# 1                                                NaN                 NaN
# 2  1 color map, 115 x 92 centimeters, folded in c...  Harimaya Katsugorō
# 3  1 print: woodcut, color ; 29.0 x 21.3 centimeters                 NaN
# 4     1 manuscript map : color ; 60 x 86 centimeters                 NaN

# %%
loc_df.head()
# Out:
#                                                title  \
# 0  Antietam, Maryland. Allan Pinkerton, President...
# 1  Chola Woman, Full-Length Portrait, Standing, F...
# 2           Maps of Ezo, Sakhalin, and Kuril Islands
# 3                          Warrior Asahina Kobayashi
# 4     Manuscript Map of Dagua River Region, Colombia
#
#                                 collection  \
# 0                                      NaN
# 1   Frank and Frances Carpenter Collection
# 2                                      NaN
# 3  Japanese Prints and Drawings Collection
# 4                                      NaN
#
#                                          description  \
# 0  At the outset of the U.S. Civil War, Mathew Br...
# 1  This photograph of a Bolivian woman is from th...
# 2  This map was made by Fujita Junsai and publish...
# 3  The Japanese art of Ukiyo-e (“Pictures of the ...
# 4  This beautiful pen-and-ink and watercolor map ...
#
#                          wdl_url         Type of Item          Institution  \
# 0  https://www.wdl.org/en/item/1  Prints, Photographs  Library of Congress
# 1  https://www.wdl.org/en/item/2  Prints, Photographs  Library of Congress
# 2  https://www.wdl.org/en/item/3                 Maps  Library of Congress
# 3  https://www.wdl.org/en/item/4  Prints, Photographs  Library of Congress
# 4  https://www.wdl.org/en/item/5                 Maps  Library of Congress
#
#   Date Created Dewey Decimal Code  \
# 0   1862-10-03                973
# 1         1911                391
# 2         1854                912
# 3         1862            769|792
# 4         1764                912
#
#                                 Physical Description           Publisher
# 0                  1 negative : glass, wet collodion                 NaN
# 1                                                NaN                 NaN
# 2  1 color map, 115 x 92 centimeters, folded in c...  Harimaya Katsugorō
# 3  1 print: woodcut, color ; 29.0 x 21.3 centimeters                 NaN
# 4     1 manuscript map : color ; 60 x 86 centimeters                 NaN

# %%
loc_df['Dewey Decimal Code'] = loc_df['Dewey Decimal Code'].replace('\|', '.', regex=True)
loc_df.head()
# Out:
#                                                title  \
# 0  Antietam, Maryland. Allan Pinkerton, President...
# 1  Chola Woman, Full-Length Portrait, Standing, F...
# 2           Maps of Ezo, Sakhalin, and Kuril Islands
# 3                          Warrior Asahina Kobayashi
# 4     Manuscript Map of Dagua River Region, Colombia
#
#                                 collection  \
# 0                                      NaN
# 1   Frank and Frances Carpenter Collection
# 2                                      NaN
# 3  Japanese Prints and Drawings Collection
# 4                                      NaN
#
#                                          description  \
# 0  At the outset of the U.S. Civil War, Mathew Br...
# 1  This photograph of a Bolivian woman is from th...
# 2  This map was made by Fujita Junsai and publish...
# 3  The Japanese art of Ukiyo-e (“Pictures of the ...
# 4  This beautiful pen-and-ink and watercolor map ...
#
#                          wdl_url         Type of Item          Institution  \
# 0  https://www.wdl.org/en/item/1  Prints, Photographs  Library of Congress
# 1  https://www.wdl.org/en/item/2  Prints, Photographs  Library of Congress
# 2  https://www.wdl.org/en/item/3                 Maps  Library of Congress
# 3  https://www.wdl.org/en/item/4  Prints, Photographs  Library of Congress
# 4  https://www.wdl.org/en/item/5                 Maps  Library of Congress
#
#   Date Created Dewey Decimal Code  \
# 0   1862-10-03                973
# 1         1911                391
# 2         1854                912
# 3         1862            769.792
# 4         1764                912
#
#                                 Physical Description           Publisher
# 0                  1 negative : glass, wet collodion                 NaN
# 1                                                NaN                 NaN
# 2  1 color map, 115 x 92 centimeters, folded in c...  Harimaya Katsugorō
# 3  1 print: woodcut, color ; 29.0 x 21.3 centimeters                 NaN
# 4     1 manuscript map : color ; 60 x 86 centimeters                 NaN

# %%
item_type_df = pd.read_csv('Resources/item_codes_new.csv', encoding='utf-8')
item_type_df
# Out:
#   item_code                 Item
# 0      prph  Prints, Photographs
# 1        mp                 Maps
# 2        bk                Books
# 3        ms          Manuscripts
# 4        mp      Motion Pictures
# 5        sr     Sound Recordings
# 6        jr             Journals
# 7        np           Newspapers

# %%
items_df = loc_df.join(item_type_df,how='outer')
items_df.drop(columns=['Type of Item','Item'],inplace=True)
items_df.head()
# Out:
#                                                title  \
# 0  Antietam, Maryland. Allan Pinkerton, President...
# 1  Chola Woman, Full-Length Portrait, Standing, F...
# 2           Maps of Ezo, Sakhalin, and Kuril Islands
# 3                          Warrior Asahina Kobayashi
# 4     Manuscript Map of Dagua River Region, Colombia
#
#                                 collection  \
# 0                                      NaN
# 1   Frank and Frances Carpenter Collection
# 2                                      NaN
# 3  Japanese Prints and Drawings Collection
# 4                                      NaN
#
#                                          description  \
# 0  At the outset of the U.S. Civil War, Mathew Br...
# 1  This photograph of a Bolivian woman is from th...
# 2  This map was made by Fujita Junsai and publish...
# 3  The Japanese art of Ukiyo-e (“Pictures of the ...
# 4  This beautiful pen-and-ink and watercolor map ...
#
#                          wdl_url          Institution Date Created  \
# 0  https://www.wdl.org/en/item/1  Library of Congress   1862-10-03
# 1  https://www.wdl.org/en/item/2  Library of Congress         1911
# 2  https://www.wdl.org/en/item/3  Library of Congress         1854
# 3  https://www.wdl.org/en/item/4  Library of Congress         1862
# 4  https://www.wdl.org/en/item/5  Library of Congress         1764
#
#   Dewey Decimal Code                               Physical Description  \
# 0                973                  1 negative : glass, wet collodion
# 1                391                                                NaN
# 2                912  1 color map, 115 x 92 centimeters, folded in c...
# 3            769.792  1 print: woodcut, color ; 29.0 x 21.3 centimeters
# 4                912     1 manuscript map : color ; 60 x 86 centimeters
#
#             Publisher item_code
# 0                 NaN      prph
# 1                 NaN        mp
# 2  Harimaya Katsugorō        bk
# 3                 NaN        ms
# 4                 NaN        mp

# %%
col_type_df = pd.read_csv('Resources/col_mapping_new.csv', encoding='utf-8')
col_type_df.head()
# Out:
#      col                               collection
# 0  col_1                           Non-Collection
# 1  col_2   Frank and Frances Carpenter Collection
# 2  col_3  Japanese Prints and Drawings Collection
# 3  col_4                Henry Harrisse Collection
# 4  col_5                    United States History

# %%
items_df = items_df.merge(col_type_df,how='outer')
items_df.drop(columns='collection',inplace=True)
items_df.head()
# Out:
#                                                title  \
# 0  Antietam, Maryland. Allan Pinkerton, President...
# 1           Maps of Ezo, Sakhalin, and Kuril Islands
# 2     Manuscript Map of Dagua River Region, Colombia
# 3                                   Map of the World
# 4  First Nerchinsk Regiment of Zabaikal Cossack T...
#
#                                          description  \
# 0  At the outset of the U.S. Civil War, Mathew Br...
# 1  This map was made by Fujita Junsai and publish...
# 2  This beautiful pen-and-ink and watercolor map ...
# 3  This late 18th-century Latin map of the world ...
# 4  The First Nerchinsk Cossack Regiment was creat...
#
#                           wdl_url                 Institution Date Created  \
# 0   https://www.wdl.org/en/item/1         Library of Congress   1862-10-03
# 1   https://www.wdl.org/en/item/3         Library of Congress         1854
# 2   https://www.wdl.org/en/item/5         Library of Congress         1764
# 3   https://www.wdl.org/en/item/7  National Library of Brazil         1775
# 4  https://www.wdl.org/en/item/18       Russian State Library         1907
#
#   Dewey Decimal Code                               Physical Description  \
# 0                973                  1 negative : glass, wet collodion
# 1                912  1 color map, 115 x 92 centimeters, folded in c...
# 2                912     1 manuscript map : color ; 60 x 86 centimeters
# 3                912                          Hand-colored engraved map
# 4                355  177 pages : illustrated, 5 sheets of illustrat...
#
#                                  Publisher item_code  col
# 0                                      NaN      prph  NaN
# 1                       Harimaya Katsugorō        bk  NaN
# 2                                      NaN        mp  NaN
# 3                     Tobias Conrad Lotter        jr  NaN
# 4  Association of R. Golik and A. Vil'borg       NaN  NaN

# %%
ins_type_df = pd.read_csv('Resources/ins_mapping_new.csv', encoding='utf-8')
ins_type_df.head()
# Out:
#   ins_key                          Institution
# 0   ins_1                  Library of Congress
# 1   ins_2           National Library of Brazil
# 2   ins_3                Russian State Library
# 3   ins_4           National Library of Russia
# 4   ins_5  Mamma Haidara Commemorative Library

# %%
items_df = items_df.merge(ins_type_df,how='outer')
items_df.drop(columns='Institution',inplace=True)
items_df.head()
# Out:
#                                                title  \
# 0  Antietam, Maryland. Allan Pinkerton, President...
# 1           Maps of Ezo, Sakhalin, and Kuril Islands
# 2     Manuscript Map of Dagua River Region, Colombia
# 3                    7th War Loan. Now--All Together
# 4                         A Chart of the Gulf Stream
#
#                                          description  \
# 0  At the outset of the U.S. Civil War, Mathew Br...
# 1  This map was made by Fujita Junsai and publish...
# 2  This beautiful pen-and-ink and watercolor map ...
# 3  C.C. Beall (1892-1967) was a commercial illust...
# 4  This map, from the Peter Force Map Collection ...
#
#                           wdl_url Date Created Dewey Decimal Code  \
# 0   https://www.wdl.org/en/item/1   1862-10-03                973
# 1   https://www.wdl.org/en/item/3         1854                912
# 2   https://www.wdl.org/en/item/5         1764                912
# 3  https://www.wdl.org/en/item/19         1945            332.940
# 4  https://www.wdl.org/en/item/20         1786            551.911
#
#                                 Physical Description  \
# 0                  1 negative : glass, wet collodion
# 1  1 color map, 115 x 92 centimeters, folded in c...
# 2     1 manuscript map : color ; 60 x 86 centimeters
# 3  1 photomechanical print (poster) : halftone, c...
# 4                                21 x 26 centimeters
#
#                          Publisher item_code  col ins_key
# 0                              NaN      prph  NaN   ins_1
# 1               Harimaya Katsugorō        bk  NaN   ins_1
# 2                              NaN        mp  NaN   ins_1
# 3  U.S. Government Printing Office       NaN  NaN   ins_1
# 4   American Philosophical Society       NaN  NaN   ins_1

# %%
pub_type_df = pd.read_csv('Resources/pub_mapping_new.csv', encoding='utf-8')
pub_type_df.head()
# Out:
#   pub_key                   Publisher
# 0   pub_1                     unknown
# 1   pub_2          Harimaya Katsugorō
# 2   pub_3    Dutch West India Company
# 3   pub_4        Tobias Conrad Lotter
# 4   pub_5  American Press Association

# %%
items_df = items_df.merge(pub_type_df,how='outer')
items_df.drop(columns='Publisher',inplace=True)
items_df.head()
# Out:
#                                                title  \
# 0  Antietam, Maryland. Allan Pinkerton, President...
# 1     Manuscript Map of Dagua River Region, Colombia
# 2  A Plan of the Rosalij Compy. Estates, the Prop...
# 3                                  Cape of Good Hope
# 4  Map of the Straits of Magellan and Part of the...
#
#                                          description  \
# 0  At the outset of the U.S. Civil War, Mathew Br...
# 1  This beautiful pen-and-ink and watercolor map ...
# 2  France and Britain vied for control of Dominic...
# 3  John Arrowsmith (1790-1873) was best known for...
# 4  This composite map of the 1785-86 scientific e...
#
#                           wdl_url Date Created Dewey Decimal Code  \
# 0   https://www.wdl.org/en/item/1   1862-10-03                973
# 1   https://www.wdl.org/en/item/5         1764                912
# 2  https://www.wdl.org/en/item/25         1776                912
# 3  https://www.wdl.org/en/item/51         1842                912
# 4  https://www.wdl.org/en/item/52         1786                912
#
#                                 Physical Description item_code  col ins_key  \
# 0                  1 negative : glass, wet collodion      prph  NaN   ins_1
# 1     1 manuscript map : color ; 60 x 86 centimeters        mp  NaN   ins_1
# 2                  1 color map, 125 x 92 centimeters       NaN  NaN   ins_1
# 3  Hand colored engraved map, sectioned and mount...       NaN  NaN   ins_1
# 4  1 pen-and-ink and watercolor manuscript map ; ...       NaN  NaN   ins_1
#
#   pub_key
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
items_df = items_df.loc[:,['title','col','description','Physical Description', 'wdl_url','ins_key','pub_key','Dewey Decimal Code','item_code','Date Created']]

# %%
items_df.head()
# Out:
#                                                title  col  \
# 0  Antietam, Maryland. Allan Pinkerton, President...  NaN
# 1     Manuscript Map of Dagua River Region, Colombia  NaN
# 2  A Plan of the Rosalij Compy. Estates, the Prop...  NaN
# 3                                  Cape of Good Hope  NaN
# 4  Map of the Straits of Magellan and Part of the...  NaN
#
#                                          description  \
# 0  At the outset of the U.S. Civil War, Mathew Br...
# 1  This beautiful pen-and-ink and watercolor map ...
# 2  France and Britain vied for control of Dominic...
# 3  John Arrowsmith (1790-1873) was best known for...
# 4  This composite map of the 1785-86 scientific e...
#
#                                 Physical Description  \
# 0                  1 negative : glass, wet collodion
# 1     1 manuscript map : color ; 60 x 86 centimeters
# 2                  1 color map, 125 x 92 centimeters
# 3  Hand colored engraved map, sectioned and mount...
# 4  1 pen-and-ink and watercolor manuscript map ; ...
#
#                           wdl_url ins_key pub_key Dewey Decimal Code  \
# 0   https://www.wdl.org/en/item/1   ins_1     NaN                973
# 1   https://www.wdl.org/en/item/5   ins_1     NaN                912
# 2  https://www.wdl.org/en/item/25   ins_1     NaN                912
# 3  https://www.wdl.org/en/item/51   ins_1     NaN                912
# 4  https://www.wdl.org/en/item/52   ins_1     NaN                912
#
#   item_code Date Created
# 0      prph   1862-10-03
# 1        mp         1764
# 2       NaN         1776
# 3       NaN         1842
# 4       NaN         1786

# %%
items_df['item_id'] = items_df.index
items_df.head()
# Out:
#                                                title  col  \
# 0  Antietam, Maryland. Allan Pinkerton, President...  NaN
# 1     Manuscript Map of Dagua River Region, Colombia  NaN
# 2  A Plan of the Rosalij Compy. Estates, the Prop...  NaN
# 3                                  Cape of Good Hope  NaN
# 4  Map of the Straits of Magellan and Part of the...  NaN
#
#                                          description  \
# 0  At the outset of the U.S. Civil War, Mathew Br...
# 1  This beautiful pen-and-ink and watercolor map ...
# 2  France and Britain vied for control of Dominic...
# 3  John Arrowsmith (1790-1873) was best known for...
# 4  This composite map of the 1785-86 scientific e...
#
#                                 Physical Description  \
# 0                  1 negative : glass, wet collodion
# 1     1 manuscript map : color ; 60 x 86 centimeters
# 2                  1 color map, 125 x 92 centimeters
# 3  Hand colored engraved map, sectioned and mount...
# 4  1 pen-and-ink and watercolor manuscript map ; ...
#
#                           wdl_url ins_key pub_key Dewey Decimal Code  \
# 0   https://www.wdl.org/en/item/1   ins_1     NaN                973
# 1   https://www.wdl.org/en/item/5   ins_1     NaN                912
# 2  https://www.wdl.org/en/item/25   ins_1     NaN                912
# 3  https://www.wdl.org/en/item/51   ins_1     NaN                912
# 4  https://www.wdl.org/en/item/52   ins_1     NaN                912
#
#   item_code Date Created  item_id
# 0      prph   1862-10-03        0
# 1        mp         1764        1
# 2       NaN         1776        2
# 3       NaN         1842        3
# 4       NaN         1786        4

# %%
# Export the mapping DataFrame to a CSV file
items_df.to_csv('Resources/items.csv', index=False)
