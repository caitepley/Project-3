# %%
import pandas as pd
import dask.dataframe as dd
from pathlib import Path
from sqlalchemy import create_engine, text

# %%
#Reading in the source file for the project
file_path = 'Resources/wdl_data_en_reduced.csv'
# Specifying encoding as'ISO-8859-1' to read file
loc_df = pd.read_csv(file_path, encoding='utf-8')
# Out:
# C:\Users\Cait\AppData\Local\Temp\ipykernel_18724\2306786982.py:4: DtypeWarning: Columns (0,20,33,34,36,37,41,42,43,49,52,54,55,62,63,66,69,70,71,72,74,76,81,82,84,85,86,87) have mixed types. Specify dtype option on import or set low_memory=False.
#   loc_df = pd.read_csv(file_path, encoding='utf-8')

# %%
loc_df.columns
# Out:
# Index(['wdl_id', 'title', 'collection', 'description', 'wdl_url',
#        'Type of Item', 'Institution', 'Photographer', 'Date Created',
#        'Subject Date', 'Place', 'Dewey Decimal Code', 'Additional Subjects',
#        'Physical Description', 'Creator', 'Publisher', 'Language', 'Artist',
#        'Cartographer', 'Note', 'Delineator', 'Author', 'Surveyor', 'Compiler',
#        'Translator', 'Contributor', 'Engraver', 'Cinematographer', 'Director',
#        'Illustrator', 'Sponsor', 'Draftsman', 'Editor', 'Corrector',
#        'Responsible Party', 'Calligrapher', 'Interviewee', 'Interviewer',
#        'Associated Name', 'Printer', 'Lithographer', 'Donor',
#        'Recording Engineer', 'Musician', 'Composer', 'Architect', 'References',
#        'Attributed Name', 'Dedicatee', 'Signer', 'Copyright Holder',
#        'Collector', 'Printmaker', 'Copyright claimant', 'Performer', 'Owner',
#        'Commentator', 'Etcher', 'Wood-engraver', 'Scribe',
#        'Author of Introduction, etc.', 'Author of Afterword, Colophon, etc.',
#        'Scientific advisor', 'Speaker', 'Commentator for Written Text',
#        'Illuminator', 'Librettist', 'Client', 'Transcriber', 'Collaborator',
#        'Producer', 'Videographer', 'Vocalist', 'Patron', 'Funder', 'Annotator',
#        'Woodcutter', 'Designer', 'Author in Quotations or Text Extracts',
#        'Lyricist', 'Type Designer', 'Animator', 'Writer of added text',
#        'Project Director', 'Dubious Author', 'Censor', 'Engineer', 'Lead',
#        'Publishing Director', 'Singer', 'Binder', 'Originator', 'Typographer',
#        'Book producer', 'Narrator', 'Colorist', 'Arranger', 'Recipient',
#        'Correspondent'],
#       dtype='object')

# %%
loc_df['item_id'] = loc_df.index
loc_df.head()
# Out:
#   wdl_id                                              title  \
# 0      1  Antietam, Maryland. Allan Pinkerton, President...
# 1      2  Chola Woman, Full-Length Portrait, Standing, F...
# 2      3           Maps of Ezo, Sakhalin, and Kuril Islands
# 3      4                          Warrior Asahina Kobayashi
# 4      5     Manuscript Map of Dagua River Region, Colombia
#
#                                 collection  \
# 0                                      NaN
# 1   Frank and Frances Carpenter Collection
# 2                                      NaN
# 3  Japanese Prints and Drawings Collection
# 4                                      NaN
#
#                                          description  \
# 0  At the outset of the U.S. Civil War, Mathew Br...
# 1  This photograph of a Bolivian woman is from th...
# 2  This map was made by Fujita Junsai and publish...
# 3  The Japanese art of Ukiyo-e (“Pictures of the ...
# 4  This beautiful pen-and-ink and watercolor map ...
#
#                          wdl_url         Type of Item          Institution  \
# 0  https://www.wdl.org/en/item/1  Prints, Photographs  Library of Congress
# 1  https://www.wdl.org/en/item/2  Prints, Photographs  Library of Congress
# 2  https://www.wdl.org/en/item/3                 Maps  Library of Congress
# 3  https://www.wdl.org/en/item/4  Prints, Photographs  Library of Congress
# 4  https://www.wdl.org/en/item/5                 Maps  Library of Congress
#
#                     Photographer Date Created Subject Date  ... Binder  \
# 0  Gardner, Alexander, 1821-1882   1862-10-03   1862-10-03  ...    NaN
# 1      Vargas, Max T., 1874–1959         1911    1900/1923  ...    NaN
# 2                            NaN         1854         1854  ...    NaN
# 3                            NaN         1862         1862  ...    NaN
# 4                            NaN         1764         1764  ...    NaN
#
#   Originator Typographer Book producer Narrator Colorist Arranger Recipient  \
# 0        NaN         NaN           NaN      NaN      NaN      NaN       NaN
# 1        NaN         NaN           NaN      NaN      NaN      NaN       NaN
# 2        NaN         NaN           NaN      NaN      NaN      NaN       NaN
# 3        NaN         NaN           NaN      NaN      NaN      NaN       NaN
# 4        NaN         NaN           NaN      NaN      NaN      NaN       NaN
#
#   Correspondent item_id
# 0           NaN       0
# 1           NaN       1
# 2           NaN       2
# 3           NaN       3
# 4           NaN       4
#
# [5 rows x 100 columns]

# %%
loc_df.drop(columns=['wdl_id','Creator','Delineator', 'Author', 'Surveyor', 'Compiler',
       'Translator', 'Contributor', 'Engraver', 'Cinematographer', 'Director',
       'Illustrator', 'Sponsor', 'Draftsman', 'Editor', 'Corrector',
       'Responsible Party', 'Calligrapher', 'Interviewee', 'Interviewer',
       'Associated Name', 'Printer', 'Lithographer', 'Donor',
       'Recording Engineer', 'Musician', 'Composer', 'Architect', 'References',
       'Attributed Name', 'Dedicatee', 'Signer', 'Copyright Holder',
       'Collector', 'Printmaker', 'Copyright claimant', 'Performer', 'Owner',
       'Commentator', 'Etcher', 'Wood-engraver', 'Scribe',
       'Author of Introduction, etc.', 'Author of Afterword, Colophon, etc.',
       'Scientific advisor', 'Speaker', 'Commentator for Written Text',
       'Illuminator', 'Librettist', 'Client', 'Transcriber', 'Collaborator',
       'Producer', 'Videographer', 'Vocalist', 'Patron', 'Funder', 'Annotator',
       'Woodcutter', 'Designer', 'Author in Quotations or Text Extracts',
       'Lyricist', 'Type Designer', 'Animator', 'Writer of added text',
       'Project Director', 'Dubious Author', 'Censor', 'Engineer', 'Lead',
       'Publishing Director', 'Singer', 'Binder', 'Originator', 'Typographer',
       'Book producer', 'Narrator', 'Colorist', 'Arranger', 'Recipient',
       'Correspondent','Creator','Language', 'Artist',
       'Cartographer', 'Note','Photographer','Place','Subject Date','Additional Subjects'], inplace=True)
loc_df.head()
# Out:
#                                                title  \
# 0  Antietam, Maryland. Allan Pinkerton, President...
# 1  Chola Woman, Full-Length Portrait, Standing, F...
# 2           Maps of Ezo, Sakhalin, and Kuril Islands
# 3                          Warrior Asahina Kobayashi
# 4     Manuscript Map of Dagua River Region, Colombia
#
#                                 collection  \
# 0                                      NaN
# 1   Frank and Frances Carpenter Collection
# 2                                      NaN
# 3  Japanese Prints and Drawings Collection
# 4                                      NaN
#
#                                          description  \
# 0  At the outset of the U.S. Civil War, Mathew Br...
# 1  This photograph of a Bolivian woman is from th...
# 2  This map was made by Fujita Junsai and publish...
# 3  The Japanese art of Ukiyo-e (“Pictures of the ...
# 4  This beautiful pen-and-ink and watercolor map ...
#
#                          wdl_url         Type of Item          Institution  \
# 0  https://www.wdl.org/en/item/1  Prints, Photographs  Library of Congress
# 1  https://www.wdl.org/en/item/2  Prints, Photographs  Library of Congress
# 2  https://www.wdl.org/en/item/3                 Maps  Library of Congress
# 3  https://www.wdl.org/en/item/4  Prints, Photographs  Library of Congress
# 4  https://www.wdl.org/en/item/5                 Maps  Library of Congress
#
#   Date Created Dewey Decimal Code  \
# 0   1862-10-03                973
# 1         1911                391
# 2         1854                912
# 3         1862            769|792
# 4         1764                912
#
#                                 Physical Description           Publisher  \
# 0                  1 negative : glass, wet collodion                 NaN
# 1                                                NaN                 NaN
# 2  1 color map, 115 x 92 centimeters, folded in c...  Harimaya Katsugorō
# 3  1 print: woodcut, color ; 29.0 x 21.3 centimeters                 NaN
# 4     1 manuscript map : color ; 60 x 86 centimeters                 NaN
#
#    item_id
# 0        0
# 1        1
# 2        2
# 3        3
# 4        4

# %%
loc_df = loc_df.loc[:,['item_id','title','collection','description','Physical Description', 'wdl_url','Institution','Publisher','Dewey Decimal Code','Type of Item','Date Created']]

# %%
loc_df.head()
# Out:
#    item_id                                              title  \
# 0        0  Antietam, Maryland. Allan Pinkerton, President...
# 1        1  Chola Woman, Full-Length Portrait, Standing, F...
# 2        2           Maps of Ezo, Sakhalin, and Kuril Islands
# 3        3                          Warrior Asahina Kobayashi
# 4        4     Manuscript Map of Dagua River Region, Colombia
#
#                                 collection  \
# 0                                      NaN
# 1   Frank and Frances Carpenter Collection
# 2                                      NaN
# 3  Japanese Prints and Drawings Collection
# 4                                      NaN
#
#                                          description  \
# 0  At the outset of the U.S. Civil War, Mathew Br...
# 1  This photograph of a Bolivian woman is from th...
# 2  This map was made by Fujita Junsai and publish...
# 3  The Japanese art of Ukiyo-e (“Pictures of the ...
# 4  This beautiful pen-and-ink and watercolor map ...
#
#                                 Physical Description  \
# 0                  1 negative : glass, wet collodion
# 1                                                NaN
# 2  1 color map, 115 x 92 centimeters, folded in c...
# 3  1 print: woodcut, color ; 29.0 x 21.3 centimeters
# 4     1 manuscript map : color ; 60 x 86 centimeters
#
#                          wdl_url          Institution           Publisher  \
# 0  https://www.wdl.org/en/item/1  Library of Congress                 NaN
# 1  https://www.wdl.org/en/item/2  Library of Congress                 NaN
# 2  https://www.wdl.org/en/item/3  Library of Congress  Harimaya Katsugorō
# 3  https://www.wdl.org/en/item/4  Library of Congress                 NaN
# 4  https://www.wdl.org/en/item/5  Library of Congress                 NaN
#
#   Dewey Decimal Code         Type of Item Date Created
# 0                973  Prints, Photographs   1862-10-03
# 1                391  Prints, Photographs         1911
# 2                912                 Maps         1854
# 3            769|792  Prints, Photographs         1862
# 4                912                 Maps         1764

# %%
loc_df['Dewey Decimal Code'] = loc_df['Dewey Decimal Code'].replace('\|', '.', regex=True)
loc_df.head()
# Out:
#    item_id                                              title  \
# 0        0  Antietam, Maryland. Allan Pinkerton, President...
# 1        1  Chola Woman, Full-Length Portrait, Standing, F...
# 2        2           Maps of Ezo, Sakhalin, and Kuril Islands
# 3        3                          Warrior Asahina Kobayashi
# 4        4     Manuscript Map of Dagua River Region, Colombia
#
#                                 collection  \
# 0                                      NaN
# 1   Frank and Frances Carpenter Collection
# 2                                      NaN
# 3  Japanese Prints and Drawings Collection
# 4                                      NaN
#
#                                          description  \
# 0  At the outset of the U.S. Civil War, Mathew Br...
# 1  This photograph of a Bolivian woman is from th...
# 2  This map was made by Fujita Junsai and publish...
# 3  The Japanese art of Ukiyo-e (“Pictures of the ...
# 4  This beautiful pen-and-ink and watercolor map ...
#
#                                 Physical Description  \
# 0                  1 negative : glass, wet collodion
# 1                                                NaN
# 2  1 color map, 115 x 92 centimeters, folded in c...
# 3  1 print: woodcut, color ; 29.0 x 21.3 centimeters
# 4     1 manuscript map : color ; 60 x 86 centimeters
#
#                          wdl_url          Institution           Publisher  \
# 0  https://www.wdl.org/en/item/1  Library of Congress                 NaN
# 1  https://www.wdl.org/en/item/2  Library of Congress                 NaN
# 2  https://www.wdl.org/en/item/3  Library of Congress  Harimaya Katsugorō
# 3  https://www.wdl.org/en/item/4  Library of Congress                 NaN
# 4  https://www.wdl.org/en/item/5  Library of Congress                 NaN
#
#   Dewey Decimal Code         Type of Item Date Created
# 0                973  Prints, Photographs   1862-10-03
# 1                391  Prints, Photographs         1911
# 2                912                 Maps         1854
# 3            769.792  Prints, Photographs         1862
# 4                912                 Maps         1764

# %%
item_type_df = pd.read_csv('item_codes_new', encoding='utf-8')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 item_type_df = pd.read_csv('item_codes_new', encoding='utf-8')
#
# File c:\Users\Cait\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\Cait\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:611, in _read(filepath_or_buffer, kwds)
#     608 _validate_names(kwds.get("names", None))
#     610 # Create the parser.
# --> 611 parser = TextFileReader(filepath_or_buffer, **kwds)
#     613 if chunksize or iterator:
#     614     return parser
#
# File c:\Users\Cait\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1448, in TextFileReader.__init__(self, f, engine, **kwds)
#    1445     self.options["has_index_names"] = kwds["has_index_names"]
#    1447 self.handles: IOHandles | None = None
# -> 1448 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\Cait\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1705, in TextFileReader._make_engine(self, f, engine)
#    1703     if "b" not in mode:
#    1704         mode += "b"
# -> 1705 self.handles = get_handle(
#    1706     f,
#    1707     mode,
#    1708     encoding=self.options.get("encoding", None),
#    1709     compression=self.options.get("compression", None),
#    1710     memory_map=self.options.get("memory_map", False),
#    1711     is_text=is_text,
#    1712     errors=self.options.get("encoding_errors", "strict"),
#    1713     storage_options=self.options.get("storage_options", None),
#    1714 )
#    1715 assert self.handles is not None
#    1716 f = self.handles.handle
#
# File c:\Users\Cait\anaconda3\Lib\site-packages\pandas\io\common.py:872, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#    (...)
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
# --> 872         handle = open(handle, ioargs.mode)
#     873     handles.append(handle)
#     875 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'item_codes_new'
