# %%
import dask

if dask.__version__:
    print(f"Dask version {dask.__version__} is installed.")
else:
    print("Dask is not installed. You can install it using 'conda install dask' or 'pip install dask[complete]'.")
# Out:
# Dask version 2022.7.0 is installed.

# %%
import pandas as pd
import dask.dataframe as dd
from pathlib import Path
from sqlalchemy import create_engine, text

# %%
#Reading in the source file for the project
   
#file_path = r"C:/Desktop/Analysis Projects/LOC Subset.csv"
file_path = r'C:/Desktop/Analysis Projects/Project-3/wdl_data_en_reduced.csv'
# Specifying encoding as'ISO-8859-1' to read file
loc_df = pd.read_csv(file_path, encoding='utf-8')

#Prints the Dask DataFrame structure in which it prints the column headings and datatypes 
print(loc_df)
# Out:
#                                                  wdl_id  \
# 0                                                     1
# 1                                                     2
# 2                                                     3
# 3                                                     4
# 4                                                     5
# ...                                                 ...
# 23860                                             13569
# 23861                                             13570
# 23862                                             13571
# 23863                                             13572
# 23864  >>>>>>> db06b73e751773811f4a728b8efff5b6d1b0332e
#
#                                                    title  \
# 0      Antietam, Maryland. Allan Pinkerton, President...
# 1      Chola Woman, Full-Length Portrait, Standing, F...
# 2               Maps of Ezo, Sakhalin, and Kuril Islands
# 3                              Warrior Asahina Kobayashi
# 4         Manuscript Map of Dagua River Region, Colombia
# ...                                                  ...
# 23860  Zhvandūn, Number 27, Saturday, September 22, 1973
# 23861  Zhvandūn, Numbers 28-29, Saturday, October 6, ...
# 23862    Zhvandūn, Number 30, Saturday, October 13, 1973
# 23863    Zhvandūn, Number 31, Saturday, October 20, 1973
# 23864                                                NaN
#
#                                     collection  \
# 0                                          NaN
# 1       Frank and Frances Carpenter Collection
# 2                                          NaN
# 3      Japanese Prints and Drawings Collection
# 4                                          NaN
# ...                                        ...
# 23860                        Zhvandūn Magazine
# 23861                        Zhvandūn Magazine
# 23862                        Zhvandūn Magazine
# 23863                        Zhvandūn Magazine
# 23864                                      NaN
#
#                                              description  \
# 0      At the outset of the U.S. Civil War, Mathew Br...
# 1      This photograph of a Bolivian woman is from th...
# 2      This map was made by Fujita Junsai and publish...
# 3      The Japanese art of Ukiyo-e (“Pictures of the ...
# 4      This beautiful pen-and-ink and watercolor map ...
# ...                                                  ...
# 23860  Zhvandūn, generally known as “Zhwandun,” was o...
# 23861  Zhvandūn, generally known as “Zhwandun,” was o...
# 23862  Zhvandūn, generally known as “Zhwandun,” was o...
# 23863  Zhvandūn, generally known as “Zhwandun,” was o...
# 23864                                                NaN
#
#                                  wdl_url         Type of Item  \
# 0          https://www.wdl.org/en/item/1  Prints, Photographs
# 1          https://www.wdl.org/en/item/2  Prints, Photographs
# 2          https://www.wdl.org/en/item/3                 Maps
# 3          https://www.wdl.org/en/item/4  Prints, Photographs
# 4          https://www.wdl.org/en/item/5                 Maps
# ...                                  ...                  ...
# 23860  https://www.wdl.org/en/item/13569             Journals
# 23861  https://www.wdl.org/en/item/13570             Journals
# 23862  https://www.wdl.org/en/item/13571             Journals
# 23863  https://www.wdl.org/en/item/13572             Journals
# 23864                                NaN                  NaN
#
#                Institution                   Photographer Date Created  \
# 0      Library of Congress  Gardner, Alexander, 1821-1882   1862-10-03
# 1      Library of Congress      Vargas, Max T., 1874–1959         1911
# 2      Library of Congress                            NaN         1854
# 3      Library of Congress                            NaN         1862
# 4      Library of Congress                            NaN         1764
# ...                    ...                            ...          ...
# 23860  Library of Congress                Vazīrī, Muṣṭafá    9/22/1973
# 23861  Library of Congress                            NaN    10/6/1973
# 23862  Library of Congress                            NaN   10/13/1973
# 23863  Library of Congress                            NaN   10/20/1973
# 23864                  NaN                            NaN          NaN
#
#       Subject Date  ... Singer Binder Originator Typographer Book producer  \
# 0       1862-10-03  ...    NaN    NaN        NaN         NaN           NaN
# 1        1900/1923  ...    NaN    NaN        NaN         NaN           NaN
# 2             1854  ...    NaN    NaN        NaN         NaN           NaN
# 3             1862  ...    NaN    NaN        NaN         NaN           NaN
# 4             1764  ...    NaN    NaN        NaN         NaN           NaN
# ...            ...  ...    ...    ...        ...         ...           ...
# 23860    9/22/1973  ...    NaN    NaN        NaN         NaN           NaN
# 23861    10/6/1973  ...    NaN    NaN        NaN         NaN           NaN
# 23862   10/13/1973  ...    NaN    NaN        NaN         NaN           NaN
# 23863   10/20/1973  ...    NaN    NaN        NaN         NaN           NaN
# 23864          NaN  ...    NaN    NaN        NaN         NaN           NaN
#
#       Narrator Colorist Arranger Recipient Correspondent
# 0          NaN      NaN      NaN       NaN           NaN
# 1          NaN      NaN      NaN       NaN           NaN
# 2          NaN      NaN      NaN       NaN           NaN
# 3          NaN      NaN      NaN       NaN           NaN
# 4          NaN      NaN      NaN       NaN           NaN
# ...        ...      ...      ...       ...           ...
# 23860      NaN      NaN      NaN       NaN           NaN
# 23861      NaN      NaN      NaN       NaN           NaN
# 23862      NaN      NaN      NaN       NaN           NaN
# 23863      NaN      NaN      NaN       NaN           NaN
# 23864      NaN      NaN      NaN       NaN           NaN
#
# [23865 rows x 99 columns]
# C:\Users\acwim\AppData\Local\Temp\ipykernel_17264\501014329.py:6: DtypeWarning: Columns (0,20,33,34,36,37,41,42,43,49,52,54,55,62,63,66,69,70,71,72,74,76,84,85,86,87,88,89,90,91,92,93,94,95,96,97,98) have mixed types. Specify dtype option on import or set low_memory=False.
#   loc_df = pd.read_csv(file_path, encoding='utf-8')

# %%
# Count of the number of columns and rows in dataframe
column_count = len(loc_df.columns)
row_count = len(loc_df)


# Print results of columns and rows
print("Number of columns:", column_count)
print("Number of records in the DataFrame:", row_count)
# Out:
# Number of columns: 99
# Number of records in the DataFrame: 23865

# %%
loc_df.columns
# Out:
# Index(['wdl_id', 'title', 'collection', 'description', 'wdl_url',
#        'Type of Item', 'Institution', 'Photographer', 'Date Created',
#        'Subject Date', 'Place', 'Dewey Decimal Code', 'Additional Subjects',
#        'Physical Description', 'Creator', 'Publisher', 'Language', 'Artist',
#        'Cartographer', 'Note', 'Delineator', 'Author', 'Surveyor', 'Compiler',
#        'Translator', 'Contributor', 'Engraver', 'Cinematographer', 'Director',
#        'Illustrator', 'Sponsor', 'Draftsman', 'Editor', 'Corrector',
#        'Responsible Party', 'Calligrapher', 'Interviewee', 'Interviewer',
#        'Associated Name', 'Printer', 'Lithographer', 'Donor',
#        'Recording Engineer', 'Musician', 'Composer', 'Architect', 'References',
#        'Attributed Name', 'Dedicatee', 'Signer', 'Copyright Holder',
#        'Collector', 'Printmaker', 'Copyright claimant', 'Performer', 'Owner',
#        'Commentator', 'Etcher', 'Wood-engraver', 'Scribe',
#        'Author of Introduction, etc.', 'Author of Afterword, Colophon, etc.',
#        'Scientific advisor', 'Speaker', 'Commentator for Written Text',
#        'Illuminator', 'Librettist', 'Client', 'Transcriber', 'Collaborator',
#        'Producer', 'Videographer', 'Vocalist', 'Patron', 'Funder', 'Annotator',
#        'Woodcutter', 'Designer', 'Author in Quotations or Text Extracts',
#        'Lyricist', 'Type Designer', 'Animator', 'Writer of added text',
#        'Project Director', 'Dubious Author', 'Censor', 'Engineer', 'Lead',
#        'Publishing Director', 'Singer', 'Binder', 'Originator', 'Typographer',
#        'Book producer', 'Narrator', 'Colorist', 'Arranger', 'Recipient',
#        'Correspondent'],
#       dtype='object')

# %%
#List of columns to remove
columns_to_remove = ['Artist',
       'Cartographer', 'Note', 'Delineator', 'Author', 'Surveyor', 'Compiler',
       'Translator', 'Contributor', 'Engraver', 'Cinematographer', 'Director',
       'Illustrator', 'Sponsor', 'Draftsman', 'Editor', 'Corrector',
       'Responsible Party', 'Calligrapher', 'Interviewee', 'Interviewer',
       'Associated Name', 'Printer', 'Lithographer', 'Donor',
       'Recording Engineer', 'Musician', 'Composer', 'Architect', 'References',
       'Attributed Name', 'Dedicatee', 'Signer', 'Copyright Holder',
       'Collector', 'Printmaker', 'Copyright claimant', 'Performer', 'Owner',
       'Commentator', 'Etcher', 'Wood-engraver', 'Scribe',
       'Author of Introduction, etc.', 'Author of Afterword, Colophon, etc.',
       'Scientific advisor', 'Speaker', 'Commentator for Written Text',
       'Illuminator', 'Librettist', 'Client', 'Transcriber', 'Collaborator',
       'Producer', 'Videographer', 'Vocalist', 'Patron', 'Funder', 'Annotator',
       'Woodcutter', 'Designer', 'Author in Quotations or Text Extracts',
       'Lyricist', 'Type Designer', 'Animator', 'Writer of added text',
       'Project Director', 'Dubious Author', 'Censor', 'Engineer', 'Lead',
       'Publishing Director', 'Singer', 'Binder', 'Originator', 'Typographer',
       'Book producer', 'Narrator', 'Colorist', 'Arranger', 'Recipient',
       'Correspondent','Photographer']

# Remove only the specified columns
loc2_df = loc_df.drop(columns=columns_to_remove)

# %%
# Count of the number of columns and rows in dataframe
column_count = len(loc2_df.columns)

# Print results of columns and rows
print("Number of columns:", column_count)

loc2_df.columns
# Out:
# Number of columns: 16
# Index(['wdl_id', 'title', 'collection', 'description', 'wdl_url',
#        'Type of Item', 'Institution', 'Date Created', 'Subject Date', 'Place',
#        'Dewey Decimal Code', 'Additional Subjects', 'Physical Description',
#        'Creator', 'Publisher', 'Language'],
#       dtype='object')

# %%
#Isolate the Type of Item for the Item_Type Table
#Calculate the number of unique authors in the DataFrame
#item_count = len(loc2_df['Type of Item'].unique())
item_type = (loc2_df['Type of Item'].unique())
print(item_type)
# Out:
# ['Prints, Photographs' 'Maps' 'Books' 'Manuscripts' 'Motion Pictures'
#  'Sound Recordings' 'Journals' 'Newspapers' nan 'Type of Item']

# %%
# Define a dictionary to map item types to codes
type_code_mapping = {
    'Prints, Photographs': 'prph',
    'Maps': 'mp',
    'Books': 'bk',
    'Manuscripts': 'ms',
    'Motion Pictures': 'mp',
    'Sound Recordings': 'sr',
    'Journals': 'jr',
    'Newspapers': 'np'
}

# Add a new column 'Item Code' based on the mapping
loc2_df['Item Code'] = loc2_df['Type of Item'].map(type_code_mapping)

# Print the updated DataFrame
print(loc2_df)
# Out:
#                                                  wdl_id  \
# 0                                                     1
# 1                                                     2
# 2                                                     3
# 3                                                     4
# 4                                                     5
# ...                                                 ...
# 23860                                             13569
# 23861                                             13570
# 23862                                             13571
# 23863                                             13572
# 23864  >>>>>>> db06b73e751773811f4a728b8efff5b6d1b0332e
#
#                                                    title  \
# 0      Antietam, Maryland. Allan Pinkerton, President...
# 1      Chola Woman, Full-Length Portrait, Standing, F...
# 2               Maps of Ezo, Sakhalin, and Kuril Islands
# 3                              Warrior Asahina Kobayashi
# 4         Manuscript Map of Dagua River Region, Colombia
# ...                                                  ...
# 23860  Zhvandūn, Number 27, Saturday, September 22, 1973
# 23861  Zhvandūn, Numbers 28-29, Saturday, October 6, ...
# 23862    Zhvandūn, Number 30, Saturday, October 13, 1973
# 23863    Zhvandūn, Number 31, Saturday, October 20, 1973
# 23864                                                NaN
#
#                                     collection  \
# 0                                          NaN
# 1       Frank and Frances Carpenter Collection
# 2                                          NaN
# 3      Japanese Prints and Drawings Collection
# 4                                          NaN
# ...                                        ...
# 23860                        Zhvandūn Magazine
# 23861                        Zhvandūn Magazine
# 23862                        Zhvandūn Magazine
# 23863                        Zhvandūn Magazine
# 23864                                      NaN
#
#                                              description  \
# 0      At the outset of the U.S. Civil War, Mathew Br...
# 1      This photograph of a Bolivian woman is from th...
# 2      This map was made by Fujita Junsai and publish...
# 3      The Japanese art of Ukiyo-e (“Pictures of the ...
# 4      This beautiful pen-and-ink and watercolor map ...
# ...                                                  ...
# 23860  Zhvandūn, generally known as “Zhwandun,” was o...
# 23861  Zhvandūn, generally known as “Zhwandun,” was o...
# 23862  Zhvandūn, generally known as “Zhwandun,” was o...
# 23863  Zhvandūn, generally known as “Zhwandun,” was o...
# 23864                                                NaN
#
#                                  wdl_url         Type of Item  \
# 0          https://www.wdl.org/en/item/1  Prints, Photographs
# 1          https://www.wdl.org/en/item/2  Prints, Photographs
# 2          https://www.wdl.org/en/item/3                 Maps
# 3          https://www.wdl.org/en/item/4  Prints, Photographs
# 4          https://www.wdl.org/en/item/5                 Maps
# ...                                  ...                  ...
# 23860  https://www.wdl.org/en/item/13569             Journals
# 23861  https://www.wdl.org/en/item/13570             Journals
# 23862  https://www.wdl.org/en/item/13571             Journals
# 23863  https://www.wdl.org/en/item/13572             Journals
# 23864                                NaN                  NaN
#
#                Institution Date Created Subject Date  \
# 0      Library of Congress   1862-10-03   1862-10-03
# 1      Library of Congress         1911    1900/1923
# 2      Library of Congress         1854         1854
# 3      Library of Congress         1862         1862
# 4      Library of Congress         1764         1764
# ...                    ...          ...          ...
# 23860  Library of Congress    9/22/1973    9/22/1973
# 23861  Library of Congress    10/6/1973    10/6/1973
# 23862  Library of Congress   10/13/1973   10/13/1973
# 23863  Library of Congress   10/20/1973   10/20/1973
# 23864                  NaN          NaN          NaN
#
#                                                    Place Dewey Decimal Code  \
# 0      North America > United States of America > Mar...                973
# 1      Latin America and the Caribbean > Bolivia > La...                391
# 2      East Asia > Japan > Hokkaido|Europe > Russian ...                912
# 3                                      East Asia > Japan            769|792
# 4      Latin America and the Caribbean > Colombia > V...                912
# ...                                                  ...                ...
# 23860               Central and South Asia > Afghanistan            079|958
# 23861               Central and South Asia > Afghanistan            079|958
# 23862               Central and South Asia > Afghanistan            079|958
# 23863               Central and South Asia > Afghanistan            079|958
# 23864                                                NaN                NaN
#
#                                      Additional Subjects  \
# 0      Antietam, Battle of, Maryland, 1862|Generals|L...
# 1                             Portrait photographs|Women
# 2                                                    NaN
# 3      Actors|Costumes|Japanese drama|Portrait prints...
# 4                                                 Rivers
# ...                                                  ...
# 23860  Library of Congress Afghanistan Project|Manner...
# 23861  Library of Congress Afghanistan Project|Manner...
# 23862  Library of Congress Afghanistan Project|Manner...
# 23863  Israel-Arab War, 1973|Library of Congress Afgh...
# 23864                                                NaN
#
#                                     Physical Description         Creator  \
# 0                      1 negative : glass, wet collodion             NaN
# 1                                                    NaN             NaN
# 2      1 color map, 115 x 92 centimeters, folded in c...  Fujita, Tonsai
# 3      1 print: woodcut, color ; 29.0 x 21.3 centimeters             NaN
# 4         1 manuscript map : color ; 60 x 86 centimeters             NaN
# ...                                                  ...             ...
# 23860                                  35-37 centimeters             NaN
# 23861                                  35-37 centimeters             NaN
# 23862                                  35-37 centimeters             NaN
# 23863                                  35-37 centimeters             NaN
# 23864                                                NaN             NaN
#
#                                                Publisher        Language  \
# 0                                                    NaN             NaN
# 1                                                    NaN             NaN
# 2                                     Harimaya Katsugorō        Japanese
# 3                                                    NaN        Japanese
# 4                                                    NaN         Spanish
# ...                                                  ...             ...
# 23860  Ministry of Information and Culture and Union ...  Persian|Pushto
# 23861  Ministry of Information and Culture and Union ...  Persian|Pushto
# 23862  Ministry of Information and Culture and Union ...  Persian|Pushto
# 23863  Ministry of Information and Culture and Union ...  Persian|Pushto
# 23864                                                NaN             NaN
#
#       Item Code
# 0          prph
# 1          prph
# 2            mp
# 3          prph
# 4            mp
# ...         ...
# 23860        jr
# 23861        jr
# 23862        jr
# 23863        jr
# 23864       NaN
#
# [23865 rows x 17 columns]

# %%
# Create a DataFrame with unique item codes and their corresponding item types
unique_item_code_df = pd.DataFrame(list(type_code_mapping.items()), columns=['Type of Item', 'Item Code'])

# Export to CSV file
unique_item_code_df.to_csv('unique_item_codes.csv', index=False)

# %%
#Isolate the Collection Type for the Collection_Type Table
#Calculate the number of unique authors in the DataFrame
collection_count = len(loc_df['collection'].unique())
collection_type = (loc_df['collection'].unique())
print(collection_count)
print(collection_type)
# Out:
# 183
# [nan 'Frank and Frances Carpenter Collection'
#  'Japanese Prints and Drawings Collection' 'Henry Harrisse Collection'
#  'United States History' 'American Imprint Collection'
#  'Geographic Card Set of the Russian Empire'
#  'Lessing J. Rosenwald Collection'
#  'William C. Brumfield Photograph Collection' 'Paper Print Collection'
#  'Thereza Christina Maria Collection' 'World War I' 'World History'
#  'Great Siberian Railway Guidebooks' 'Thomas Jefferson Library Collection'
#  'Chinese Rare Book Collection' 'Pre-1801 Imprint Collection'
#  'Hans and Hanni Kraus Sir Francis Drake Collection'
#  'Detroit Publishing Company Photograph Collection' 'Naxi Collection'
#  'Illuminated Manuscripts from Europe'
#  'Views in the Caucasus and Black Sea Area, Russian Empire'
#  'World War I Posters'
#  'Views of the Napoleonic Campaign Area, Russian Empire'
#  'Early Bulgarian Imprint Collection'
#  'Legal Acts of the Grand Duchy of Lithuania 1522-1845'
#  'Rubbings of Inscriptions on Metal and Stone'
#  'George Grantham Bain Collection' 'Views of the Austro-Hungarian Empire'
#  'Juvenile Collection'
#  'Geographical Atlas of the Russian Empire, the Kingdom of Poland, and the Grand Duchy of Finland'
#  'Various Views and Studies, Russian Empire and Europe'
#  'Cinémathèque française Collection' 'Maggs Purchase Map Collection'
#  'Relaciones Geográficas of Mexico and Guatemala, 1577-1585, Joaquín García Icazbalceta Manuscript Collection'
#  'Visual Materials from the Papers of John D. Whiting'
#  'Views in Central Asia, Russian Empire'
#  'American Colonization Society Map Collection'
#  'Islamic Manuscripts from Mali'
#  'Works of the Provisional Canalization of the São Pedro River'
#  'Jay I. Kislak Collection'
#  'Arabic and Islamic Science and Its Influence on the Western Scientific Tradition: Historical and Political Background'
#  'Images from the Turkestan Album: Historical Part'
#  'African Section Pamphlet Collection'
#  'Landscape and Marine Views of Norway' 'Views of Montenegro'
#  'Taipei During the Japanese Occupation Period'
#  'Japanese Rare Book Collection' 'The Siege of Paris: 1870–1871'
#  'Views of Petrópolis' 'Minas and Rio Railway, Brazil'
#  'Paranaguá to Curitiba Railway, Brazil' 'The Photographic Album'
#  'The Brazilian Astronomical Commission: Transit of Venus on December 6, 1882'
#  'Russian Scientific-Commercial Expedition to China, 1874-75'
#  'Peace Handbooks' 'Selections of Arabic, Persian and Ottoman Calligraphy'
#  'G. Eric and Edith Matson Photograph Collection'
#  'Views of People and Sites in Algeria'
#  'Arabic and Islamic Science and Its Influence on the Western Scientific Tradition: Astronomy'
#  'Arabic and Islamic Science and Its Influence on the Western Scientific Tradition: Mathematics'
#  'Abdul-Hamid II Collection' 'Views of Architecture and People in Tunisia'
#  'Images from the Turkestan Album: Ethnographic Part'
#  'Images from the Turkestan Album'
#  'Views of Architecture and Other Sites in Copenhagen, Denmark'
#  'Views of Belgrade, Serbia'
#  'Landscape and Marine Views of Norway and Sweden' 'Views of Germany'
#  'The Eran Laor Cartographic Collection'
#  'Columbus Memorial Library (OAS) Photograph Collection'
#  "Bašagic's Collection of Islamic Manuscripts"
#  'Ansel Adams Photographs of National Parks and Monuments, 1941-1942'
#  'Photographic Prints Documenting Programs and Activities of the Bureau of Agricultural Economics and Predecessor Agencies, Compiled ca. 1922 - ca. 1947'
#  "Documeria: The Environmental Protection Agency's Program to Photographically Document Subjects of Environmental Concern, Compiled 1972-1977"
#  'Arabic and Islamic Science and Its Influence on the Western Scientific Tradition: Technology'
#  'Anne S.K. Brown Military Collection' 'Woodhouse Rock Art Collection'
#  'Van der Waal Collection' 'Chinese Books, Manuscripts, Maps, and Prints'
#  'National Languages Collection' 'Dunhuang Collection'
#  'Sketches of the Amistad Captives' 'Mansuri Collection'
#  'Robert Burns Chapbook Collection' 'Robert Burns Collection'
#  'Images from the Turkestan Album: Archaeological Part'
#  'Florida Broadsides and Other Ephemera, 1800-2000'
#  'Arabic and Islamic Science and Its Influence on the Western Scientific Tradition: Medicine'
#  'Dale M. McDonald Collection' 'Department of Commerce Collection'
#  'Florida Folklife Collection' 'Peniarth Manuscript Collection'
#  'Atlantic World' 'Lebanese Maronite Order' 'Bibliotheca Corviniana'
#  'Views of Architecture and Other Sites in Belgium'
#  'Views of Architecture, Monuments, and Other Sites in France'
#  'Paul Sbath Collection' 'Galilean Collection'
#  'Views of Architecture and Other Sites Primarily in Poland, Russia, and the Ukraine'
#  'Views of Switzerland' 'Views of Architecture and Other Sites in Italy'
#  'Papyrus Collection (Collection Erzherzog Rainer)'
#  'Picture Archives Department' 'Africana Books Collection'
#  'Chadbourne Collection of Japanese Prints'
#  'Imperial Russian Playing Cards'
#  'Barron Collier patriotic series number 2'
#  'Views along the Mariinskii Canal and River System, Russian Empire'
#  'Views in the Ural Mountains and Western Siberia, Survey of Waterways, Russian Empire'
#  'Views in the Ural Mountains, Survey of Industrial Area, Russian Empire'
#  'Views along the Murmansk Railway, Russian Empire'
#  'Sergei Mikhailovich Prokudin-Gorskii Collection'
#  'Views along the Upper Volga River, from Its Source in the Valdai Hills to Kalyazin, Russian Empire'
#  'Views along the Upper Volga River, between Yaroslavl, Vladimir, and Kostroma, Russian Empire'
#  'Views along the Upper Volga River, from Kashin to Makarev, Russian Empire'
#  'Views along the Oka River and Suzdal, Russian Empire'
#  'Long Live Japan: 100 Victories, 100 Laughs'
#  'The Expeditionary War against Russia: Tales of Laughter'
#  'Tovar Codex: Calendar Section' 'Tovar Codex: Historical Section'
#  'Archive of Early American Images'
#  'American Geographical Society Library Digital Map Collection'
#  'Archbishopric Collection' 'NEST Library'
#  'St. George Church (Urfa Collection)' 'Monastery Library'
#  'Grabill Collection' 'Colonel Edward "Tug" Bearby Wilson Collection'
#  'Siberian Letters on Birch Bark'
#  'The Process of Building the Ķegums Hydro Power Plant (1936-1940)'
#  'Views of Kiev'
#  'Paintings of the Victorious Pacification of the Zhungars'
#  'Paintings of the Victorious Pacification of the Two Jinchuans'
#  'Paintings of the Victorious Pacification of Taiwan'
#  'Paintings of the Campaign Against and Pacification of the Miao Tribes'
#  'Paintings of the Campaign against and Pacification of Zhong Miao'
#  'Early History of the Anglican Church in Uganda'
#  'El Mosquito Newspaper Collection' 'Views of People and Sites in Turkey'
#  'Souvenir of Kiev' 'Colección Comisión Corográfica'
#  'Veterans History Project' 'La Première Ligne Newspaper Collection'
#  'Philadelphia on Stone' 'Wainwright Philadelphia Lithographs'
#  'Work Projects Administration Poster Collection'
#  'Rochambeau Map Collection' 'Indian Types and Scenes'
#  'Original Sketches Made in Afghanistan during the Campaign of 1878-79 with the Peshawer Field Force'
#  'Album of Original Military and Other Drawings and Water-Colors'
#  'Feinberg-Whitman Collection' 'Gabriela Mistral Manuscripts Collection'
#  'HMML Rare Books' 'Arca Artium Rare Books' "Saint John's Rare Books"
#  'The New Generation' 'The Uganda Journal' 'Al-Zaura Newspaper Collection'
#  'Carpathian Ruthenia' 'Florentine Codex' 'Al-Iraq Newspaper Collection'
#  'Circus & Allied Arts Collection' 'The Khoikhoi at the Cape of Good Hope'
#  'Iryan Moftah Collection of Coptic Books and Manuscripts'
#  'Papers of Wilbur and Orville Wright' 'Afghanistan, 1879-80'
#  'League of Nations Archives' 'Plutei Collection' 'Views of Great Tibet'
#  'Images from Mecca' 'Feminine Elegance Magazine Collection'
#  'General Map of Central Asia' 'John M. Brown Collection'
#  'Harry A. Atwell Collection' 'Echo of Babylon Newspaper Collection'
#  'Al-Arab Newspaper Collection'
#  'Photographs of the Jing-Zhang Railway Construction'
#  'Sun of the Day Periodical Collection' 'Kabul Magazine'
#  'Zhvandūn Magazine' 'collection']

# %%
#Isolate the Collection Type for the Collection_Type Table
#Calculate the number of unique authors in the DataFrame
Institution_count = len(loc_df['Institution'].unique())
Institution_type = (loc_df['Institution'].unique())
print(Institution_count)
print(Institution_type)
# Out:
# 121
# ['Library of Congress' 'National Library of Brazil'
#  'Russian State Library' 'National Library of Russia'
#  'Mamma Haidara Commemorative Library' 'Bibliotheca Alexandrina'
#  'National Library and Archives of Egypt' 'Irish College in Paris'
#  'Vilnius University Library' 'National Library of China'
#  'Iraqi National Library and Archives' 'National Library of Uganda'
#  'University of Texas Libraries' 'National Library of Sweden'
#  'Uppsala University Library' 'Boris Yeltsin Presidential Library'
#  'National Library of France' 'Tetouan-Asmir Association'
#  'National Central Library' 'National Library of Serbia'
#  'Qatar National Library' 'Pontifical Institute of Mediaeval Studies'
#  'National Library of Israel'
#  'Columbus Memorial Library, Organization of American States'
#  'University Library in Bratislava'
#  'Center for the Study of the History of Mexico CARSO'
#  'Royal Netherlands Institute of Southeast Asian and the Caribbean Studies KITLV'
#  'U.S. National Archives and Records Administration'
#  'John Carter Brown Library' 'Wellcome Library' 'National Diet Library'
#  'Brown University Library'
#  'Berlin State Library - Prussian Cultural Heritage Foundation'
#  'University of Pretoria Library' 'Government College University Lahore'
#  'Yale University Library'
#  'National Institute of Anthropology and History INAH'
#  'University of South Carolina' 'State Library of South Australia'
#  'Walters Art Museum' 'State Library and Archives of Florida'
#  'National Library of Chile' 'National Library of Wales'
#  'National Library of the Netherlands'
#  'Allama Iqbal Library, University of Kashmir'
#  'Central Library of the Bulgarian Academy of Sciences'
#  'Holy Spirit University of Kaslik' 'Bavarian State Library'
#  'James Ford Bell Library, University of Minnesota'
#  'National Library of Korea' 'Greek-Catholic Diocese of Aleppo'
#  'University Library of Padua' 'University Library of Naples'
#  'University Library of Sassari' 'National Central Library of Florence'
#  'Smithsonian Institution' 'Austrian National Library'
#  'National Library of Naples'
#  'National Academic Library of the Republic of Kazakhstan, Astana'
#  'University of Wisconsin-Milwaukee Libraries'
#  'Near East School of Theology' 'Syriac-Orthodox Archdiocese of Aleppo'
#  'Our Lady of Balamand Patriarchal Monastery' 'Slovak National Library'
#  'National Library of Kazakhstan' 'National Library of Spain'
#  'Abu Dhabi Authority for Culture and Heritage'
#  'National Library of Latvia' 'Latvenergo AS Power Industry Museum'
#  'Latvian War Museum'
#  'National and University Library of Bosnia and Herzegovina'
#  'National Library of Norway' 'V.I. Vernadsky National Library of Ukraine'
#  'Yaroslav Mudryi National Library of Ukraine'
#  'University of Hawaii at Manoa Library' 'Romanian Academy Library'
#  'National Library of Jamaica'
#  'Scientific Library of Lviv Polytechnic National University'
#  'Autonomous University of Nuevo Leon' 'National Library of Argentina'
#  'Museum Plantin-Moretus/Print Room' 'National Library of Colombia'
#  'The Library Company of Philadelphia'
#  'National University of Kyiv Mohyla Academy Library'
#  'General Archive of the Nation' 'King Abdulaziz University Library'
#  'Pontifical Catholic University of Chile' 'Estense Library, Modena'
#  'Hill Museum & Manuscript Library'
#  'Library of the National Academy of the Lincei and of the Corsini Family'
#  'EAFIT University' 'The Municipal Library of Porto'
#  'Medicea Laurenziana Library, Florence' 'Municipal Library Intronati'
#  'National Library and Archives of the Islamic Republic of Iran'
#  'Riccardiana Library of Florence' 'National Library of Bulgaria'
#  "Illinois State University's Special Collections, Milner Library"
#  'Circus World Museum' 'The John and Mable Ringling Museum of Art'
#  'Central Scientific Library of V.N. Karazin Kharkiv National University'
#  'Royal Library (The), Denmark' 'National Library of South Africa'
#  'Folger Shakespeare Library' 'National Library of Belarus'
#  "John M. Kelly Library, University of St. Michael's College in the University of Toronto"
#  'National Library of Armenia'
#  'The American University in Cairo Rare Books and Special Collections Library'
#  'Casanatense Library' 'Library of the National Monument of Grottaferrata'
#  'United Nations Office at Geneva Library'
#  'Saxon State and University Library, Dresden' 'Alessandrina Library'
#  'National and University Library “St Kliment Ohridski” – Skopje'
#  'Educational Documentation Centre of Circus Arts (CEDAC)'
#  'The Bolshoi St. Petersburg State Circus - Museum of Circus Art'
#  'National Library of Albania' 'Cabildo of Gran Canaria, Canary Islands'
#  'National Library of Portugal' nan 'Institution']

# %% [markdown]
# TO SPLIT THE LANGUAGE COLUMN

# %%
#Isolate the Language for theLanguage Table
#Calculate the number of unique languages in the DataFrame
language_count = len(loc_df['Language'].unique())
language_type = (loc_df['Language'].unique)
print(language_count)
print(language_type)
# Out:
# 207
# <bound method Series.unique of 0                   NaN
# 1                   NaN
# 2              Japanese
# 3              Japanese
# 4               Spanish
#               ...
# 23860    Persian|Pushto
# 23861    Persian|Pushto
# 23862    Persian|Pushto
# 23863    Persian|Pushto
# 23864               NaN
# Name: Language, Length: 23865, dtype: object>

# %%
originallanguage_df=language_type
originallanguage_df
# Out:
# <bound method Series.unique of 0                   NaN
# 1                   NaN
# 2              Japanese
# 3              Japanese
# 4               Spanish
#               ...
# 23860    Persian|Pushto
# 23861    Persian|Pushto
# 23862    Persian|Pushto
# 23863    Persian|Pushto
# 23864               NaN
# Name: Language, Length: 23865, dtype: object>

# %%
# Extracting the first part and creating a new column
loc2_df['mainlanguage'] = loc2_df['Language'].str.split('|').str[0]
loc2_df
# Out:
#                                                  wdl_id  \
# 0                                                     1
# 1                                                     2
# 2                                                     3
# 3                                                     4
# 4                                                     5
# ...                                                 ...
# 23860                                             13569
# 23861                                             13570
# 23862                                             13571
# 23863                                             13572
# 23864  >>>>>>> db06b73e751773811f4a728b8efff5b6d1b0332e
#
#                                                    title  \
# 0      Antietam, Maryland. Allan Pinkerton, President...
# 1      Chola Woman, Full-Length Portrait, Standing, F...
# 2               Maps of Ezo, Sakhalin, and Kuril Islands
# 3                              Warrior Asahina Kobayashi
# 4         Manuscript Map of Dagua River Region, Colombia
# ...                                                  ...
# 23860  Zhvandūn, Number 27, Saturday, September 22, 1973
# 23861  Zhvandūn, Numbers 28-29, Saturday, October 6, ...
# 23862    Zhvandūn, Number 30, Saturday, October 13, 1973
# 23863    Zhvandūn, Number 31, Saturday, October 20, 1973
# 23864                                                NaN
#
#                                     collection  \
# 0                                          NaN
# 1       Frank and Frances Carpenter Collection
# 2                                          NaN
# 3      Japanese Prints and Drawings Collection
# 4                                          NaN
# ...                                        ...
# 23860                        Zhvandūn Magazine
# 23861                        Zhvandūn Magazine
# 23862                        Zhvandūn Magazine
# 23863                        Zhvandūn Magazine
# 23864                                      NaN
#
#                                              description  \
# 0      At the outset of the U.S. Civil War, Mathew Br...
# 1      This photograph of a Bolivian woman is from th...
# 2      This map was made by Fujita Junsai and publish...
# 3      The Japanese art of Ukiyo-e (“Pictures of the ...
# 4      This beautiful pen-and-ink and watercolor map ...
# ...                                                  ...
# 23860  Zhvandūn, generally known as “Zhwandun,” was o...
# 23861  Zhvandūn, generally known as “Zhwandun,” was o...
# 23862  Zhvandūn, generally known as “Zhwandun,” was o...
# 23863  Zhvandūn, generally known as “Zhwandun,” was o...
# 23864                                                NaN
#
#                                  wdl_url         Type of Item  \
# 0          https://www.wdl.org/en/item/1  Prints, Photographs
# 1          https://www.wdl.org/en/item/2  Prints, Photographs
# 2          https://www.wdl.org/en/item/3                 Maps
# 3          https://www.wdl.org/en/item/4  Prints, Photographs
# 4          https://www.wdl.org/en/item/5                 Maps
# ...                                  ...                  ...
# 23860  https://www.wdl.org/en/item/13569             Journals
# 23861  https://www.wdl.org/en/item/13570             Journals
# 23862  https://www.wdl.org/en/item/13571             Journals
# 23863  https://www.wdl.org/en/item/13572             Journals
# 23864                                NaN                  NaN
#
#                Institution Date Created Subject Date  \
# 0      Library of Congress   1862-10-03   1862-10-03
# 1      Library of Congress         1911    1900/1923
# 2      Library of Congress         1854         1854
# 3      Library of Congress         1862         1862
# 4      Library of Congress         1764         1764
# ...                    ...          ...          ...
# 23860  Library of Congress    9/22/1973    9/22/1973
# 23861  Library of Congress    10/6/1973    10/6/1973
# 23862  Library of Congress   10/13/1973   10/13/1973
# 23863  Library of Congress   10/20/1973   10/20/1973
# 23864                  NaN          NaN          NaN
#
#                                                    Place Dewey Decimal Code  \
# 0      North America > United States of America > Mar...                973
# 1      Latin America and the Caribbean > Bolivia > La...                391
# 2      East Asia > Japan > Hokkaido|Europe > Russian ...                912
# 3                                      East Asia > Japan            769|792
# 4      Latin America and the Caribbean > Colombia > V...                912
# ...                                                  ...                ...
# 23860               Central and South Asia > Afghanistan            079|958
# 23861               Central and South Asia > Afghanistan            079|958
# 23862               Central and South Asia > Afghanistan            079|958
# 23863               Central and South Asia > Afghanistan            079|958
# 23864                                                NaN                NaN
#
#                                      Additional Subjects  \
# 0      Antietam, Battle of, Maryland, 1862|Generals|L...
# 1                             Portrait photographs|Women
# 2                                                    NaN
# 3      Actors|Costumes|Japanese drama|Portrait prints...
# 4                                                 Rivers
# ...                                                  ...
# 23860  Library of Congress Afghanistan Project|Manner...
# 23861  Library of Congress Afghanistan Project|Manner...
# 23862  Library of Congress Afghanistan Project|Manner...
# 23863  Israel-Arab War, 1973|Library of Congress Afgh...
# 23864                                                NaN
#
#                                     Physical Description         Creator  \
# 0                      1 negative : glass, wet collodion             NaN
# 1                                                    NaN             NaN
# 2      1 color map, 115 x 92 centimeters, folded in c...  Fujita, Tonsai
# 3      1 print: woodcut, color ; 29.0 x 21.3 centimeters             NaN
# 4         1 manuscript map : color ; 60 x 86 centimeters             NaN
# ...                                                  ...             ...
# 23860                                  35-37 centimeters             NaN
# 23861                                  35-37 centimeters             NaN
# 23862                                  35-37 centimeters             NaN
# 23863                                  35-37 centimeters             NaN
# 23864                                                NaN             NaN
#
#                                                Publisher        Language  \
# 0                                                    NaN             NaN
# 1                                                    NaN             NaN
# 2                                     Harimaya Katsugorō        Japanese
# 3                                                    NaN        Japanese
# 4                                                    NaN         Spanish
# ...                                                  ...             ...
# 23860  Ministry of Information and Culture and Union ...  Persian|Pushto
# 23861  Ministry of Information and Culture and Union ...  Persian|Pushto
# 23862  Ministry of Information and Culture and Union ...  Persian|Pushto
# 23863  Ministry of Information and Culture and Union ...  Persian|Pushto
# 23864                                                NaN             NaN
#
#       Item Code mainlanguage
# 0          prph          NaN
# 1          prph          NaN
# 2            mp     Japanese
# 3          prph     Japanese
# 4            mp      Spanish
# ...         ...          ...
# 23860        jr      Persian
# 23861        jr      Persian
# 23862        jr      Persian
# 23863        jr      Persian
# 23864       NaN          NaN
#
# [23865 rows x 18 columns]

# %% [markdown]
# TO SPLIT PUBLISHER

# %%
#Isolate the Collection Type for the Collection_Type Table
#Calculate the number of unique authors in the DataFrame
Publisher_count = len(loc_df['Publisher'].unique())
Publisher_type = (loc_df['Publisher'].unique())
print(Publisher_count)
print(Publisher_type)
# Out:
# 1129
# [nan 'Harimaya Katsugorō' 'Dutch West India Company' ... 'Zhang Dingsi'
#  'Ministry of Information and Culture and Union of the Writers of the Democratic Republic of Afghanistan'
#  'Publisher']

# %% [markdown]
# Using Pandas to test creating tables and connecting to Postgresql

# %%
# pip install psycopg2
# Out:
# Requirement already satisfied: psycopg2 in c:\users\acwim\anaconda3\lib\site-packages (2.9.9)
# Note: you may need to restart the kernel to use updated packages.

# %%
import psycopg2
from psycopg2 import sql

# %%
conn = psycopg2.connect(
    dbname="EngineerDB",
    user="postgres",
    password="password",
    host="localhost",
    port="5433"
)

cursor = conn.cursor()
